# %% [markdown]
# <a href="https://colab.research.google.com/github/Boris1001/vehicles_tracking/blob/main/Cars_counter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Description

# %% [markdown]
# #Libraries

# %%
from google.colab import drive # подключаем гугл драйв диск для загрузки файлов
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

# %% [markdown]
# #Installation Yolo_v8

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 7.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 104MB/s]

# %% [markdown]
# #Черновик

# %%
start_time = time.time()
results = model(source="/content/drive/MyDrive/Test videos/АлмаАтинка_12_11_2023 10.34.25.mp4", show=True, save= True)
end_time = time.time()
execution_time = end_time - start_time

print("Время выполнения кода:", round(execution_time/60, 2), "минут")
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/6055) /content/drive/MyDrive/Test videos/АлмаАтинка_12_11_2023 10.34.25.mp4: 384x640 5 cars, 486.5ms
# video 1/1 (2/6055) /content/drive/MyDrive/Test videos/АлмаАтинка_12_11_2023 10.34.25.mp4: 384x640 7 cars, 464.1ms
# video 1/1 (3/6055) /content/drive/MyDrive/Test videos/АлмаАтинка_12_11_2023 10.34.25.mp4: 384x640 7 cars, 261.6ms
# ...

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO("yolov8n.pt")

# Open the video file
video_path = "Луначарского_12_11_2023.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()

# %%
results = model.track(source= '/content/Луначарского_12_11_2023.mp4', stream= True, persist= True, save= True)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.3 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 7.8s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect

# %%
results
# Out:
# <generator object BasePredictor.stream_inference at 0x7b628f04e260>

# %%
results = model.track(source="/content/Снимок.JPG", show=True, tracker="bytetrack.yaml")
# Out:
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.2 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 7.2s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/Снимок.JPG: 384x640 1 car, 297.9ms
# Speed: 19.8ms preprocess, 297.9ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
results = model.track(source="/content/АлмаАтинка_12_11_2023.mp4", show=True, tracker="bytetrack.yaml")
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs

# %%
https://disk.yandex.ru/d/uTcdDURetUSNCQ/АлмаАтинка_12_11_2023%2010.34.25.mp4

# %%
results = model.track(source="https://disk.yandex.ru/d/uTcdDURetUSNCQ/АлмаАтинка_12_11_2023%2010.34.25.mp4", show=True)  # Tracking with default tracker
# Out:
# Found https://disk.yandex.ru/d/uTcdDURetUSNCQ/АлмаАтинка_12_11_2023 10.34.25.mp4 locally at АлмаАтинка_12_11_2023 10.34.25.mp4
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs

# %%
cd "/content/drive/MyDrive"
# Out:
# /content/drive/MyDrive

# %%
# !git clone --recurse-submodules https://github.com/mikel-brostrom/yolov8_tracking.git
# Out:
# Cloning into 'yolov8_tracking'...
# remote: Enumerating objects: 8953, done.
# remote: Counting objects: 100% (473/473), done.
# remote: Compressing objects: 100% (206/206), done.
# remote: Total 8953 (delta 289), reused 398 (delta 264), pack-reused 8480
# Receiving objects: 100% (8953/8953), 110.49 MiB | 15.99 MiB/s, done.
# Resolving deltas: 100% (5380/5380), done.
# Updating files: 100% (174/174), done.

# %%
results = model.track(source="/content/АлмаАтинка_12_11_2023 10.34.25.mp4", show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs

# %%
cd yolov8_tracking
# Out:
# /content/yolov8_tracking

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 110.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 25.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 125.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 130.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 58.2 MB/s eta 0:00:00
# ...

# %%
# !python track.py --source АлмаАтинка_12_11_2023 10.34.25.mp4 --weights examples/weights/yolov8n.pt --save-vid
# Out:
# usage: track.py [-h] [--yolo-model YOLO_MODEL] [--reid-model REID_MODEL]
#                 [--tracking-method TRACKING_METHOD] [--source SOURCE] [--imgsz IMGSZ [IMGSZ ...]]
#                 [--conf CONF] [--iou IOU] [--device DEVICE] [--show] [--save]
#                 [--classes CLASSES [CLASSES ...]] [--project PROJECT] [--name NAME] [--exist-ok]
#                 [--half] [--vid-stride VID_STRIDE] [--show-labels] [--show-conf] [--save-txt]
#                 [--save-id-crops] [--save-mot] [--line-width LINE_WIDTH] [--per-class] [--verbose]
#                 [--vid_stride VID_STRIDE]
# track.py: error: unrecognized arguments: 10.34.25.mp4 --weights examples/weights/yolov8n.pt --save-vid

# %%
# !python track.py --source АлмаАтинка_12_11_2023.mp4 --yolo-model model --show
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 108MB/s]
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# 2023-11-13 12:23:35.638 | ERROR    | examples.detectors:get_yolo_inferer:34 - Failed to infer inference mode from yolo model name
# 2023-11-13 12:23:35.638 | ERROR    | examples.detectors:get_yolo_inferer:35 - Your model name has to contain either yolox, yolo_nas or yolov8

# %%
results
# Out:
# <generator object BasePredictor.stream_inference at 0x79bbc1b6f1b0>

# %%
results = model.track(source="https://drive.google.com/file/d/1apbYg566tqKtar_TRgypt0EHaqnC6iSR/view?usp=drive_link", show=True)  # Tracking with default tracker
# Out:
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.9 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 4.0s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-5-cc2d32b27899> in <cell line: 1>()
# ----> 1 results = model.track(source="https://drive.google.com/file/d/1apbYg566tqKtar_TRgypt0EHaqnC6iSR/view?usp=drive_link", show=True)  # Tracking with default tracker
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in track(self, source, stream, persist, **kwargs)
# ...

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Open the video file
video_path = "/content/АлмаАтинка_12_11_2023 10.34.25.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(video_path)

# %%
from IPython.display import Video

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fafa4bf0-fba0-4481-8bf6-adbb85e23d78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fafa4bf0-fba0-4481-8bf6-adbb85e23d78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Video("/content/Луначарского_12_11_2023 09.34.25.mp4")
# Out:
# <video src="/content/Луначарского_12_11_2023 09.34.25.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
import cv2
from ultralytics import YOLO

cap = cv2.VideoCapture("/content/Димитрова_12_11_2023 11.34.25.mp4")
#model = YOLO("yolov8n.pt")
while True:
  ret, frame = cap.read()
  if not ret:
    break
  results = model.track(frame, persist=True)
  boxes = results[0].boxes.xyxy.cpu().numpy().astype(int)
  ids = results[0].boxes.id.cpu().numpy().astype(int)
